# %% [markdown]
# <a href="https://colab.research.google.com/github/Fnoor68/EDGE_Django/blob/main/EDGE_File_Read_Noor_IT20030.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file=pd.read_csv("Dataset.csv")

# %%
file
# Out:
# Empty DataFrame
# Columns: [10, 50, 100, 500, 1000, 5000, 10000]
# Index: []

# %%
import sys

# %%
# !wget https://raw.githubusercontent.com/Fnoor68/EDGE_Django/refs/heads/main/Noor_Math.py
sys.path.append('/content')
from Noor_Math import print_pi_to_n_digits
# Out:
# --2024-11-07 05:40:46--  https://raw.githubusercontent.com/Fnoor68/EDGE_Django/refs/heads/main/Noor_Math.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248 [text/plain]
# Saving to: ‘Noor_Math.py.1’
#
# Noor_Math.py.1      100%[===================>]     248  --.-KB/s    in 0s
#
# 2024-11-07 05:40:46 (12.4 MB/s) - ‘Noor_Math.py.1’ saved [248/248]

# %%
for i in file:
    print("PI for Digit =  ", i," ", print_pi_to_n_digits(int(i)), end="\n")
# Out:
# PI for Digit =   10   3.1415926536
# PI for Digit =   50   3.14159265358979323846264338327950288419716939937511
# PI for Digit =   100   3.141592653589793238462643383279502884197169399375105820974944592307816406286208998628034825342117068
# PI for Digit =   500   3....
# PI for Digit =   1000   3....
# PI for Digit =   5000   3....
# PI for Digit =   10000   3....
