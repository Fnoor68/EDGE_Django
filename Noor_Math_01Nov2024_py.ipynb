# %% [markdown]
# <a href="https://colab.research.google.com/github/Fnoor68/EDGE_Django/blob/main/Noor_Math_01Nov2024_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

# %%
# !wget https://raw.githubusercontent.com/Fnoor68/EDGE_Django/refs/heads/main/Noor_Math.py
sys.path.append('/content')
from Noor_Math import *
numberOfDigits = int(input("Enter the first number a: "))  ## this code will in the Colab
print(print_pi_to_n_digits(numberOfDigits))
# Out:
# --2024-11-01 11:28:03--  https://raw.githubusercontent.com/Fnoor68/EDGE_Django/refs/heads/main/Noor_Math.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248 [text/plain]
# Saving to: ‘Noor_Math.py.3’
#
# Noor_Math.py.3      100%[===================>]     248  --.-KB/s    in 0s
#
# 2024-11-01 11:28:03 (11.0 MB/s) - ‘Noor_Math.py.3’ saved [248/248]
#
# Enter the first number a: 2000
# 3....
